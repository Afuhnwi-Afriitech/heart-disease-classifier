# %% [markdown]
# <a href="https://colab.research.google.com/github/Afuhnwi-Afriitech/heart-disease-classifier/blob/main/heart-disease.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Training a machine learning model to predict if a patient has heart disease or not
#
# what we are going to do.
#   1. problem definition
#   2. data
#   3. evaluation
#   4. modeling
#   5. experimentation

# %% [markdown]
# ## 1. Problem definition
# ##This is a classification problem and there are only 2 classes

# %% [markdown]
# ## 2. Data
# ##importing data

# %%
import pandas as pd

# %%
heart_disease = pd.read_csv("heart.csv")
heart_disease.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
x = heart_disease.drop("target", axis=1)
y = heart_disease["target"]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)
clf = RandomForestClassifier()

clf.fit(x_train, y_train)
clf.score(x_test, y_test)
# Out:
# 0.9805194805194806

# %%
len(heart_disease)
# Out:
# 1025

# %%
import pickle
pickle.dump(clf, open("heart_disease_model.pkl", "wb"))

# %%
model =  pickle.load(open("heart_disease_model.pkl", "rb"))
model.predict(x_test)[:10]
# Out:
# array([1, 1, 1, 0, 0, 1, 0, 0, 0, 1])

# %%
heart_disease.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['age'].plot(kind='hist', bins=20, title='age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...
